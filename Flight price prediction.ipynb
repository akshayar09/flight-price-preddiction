# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
# !pip install openpyxl
df = pd.read_excel(r"G:\flight price/Data_Train.xlsx")
df.head()
# Out:
# Requirement already satisfied: openpyxl in c:\users\dell\anaconda3\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\users\dell\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
#        Airline Date_of_Journey    Source  ... Total_Stops Additional_Info  Price
# 0       IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897
# 1    Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662
# 2  Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882
# 3       IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218
# 4       IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
dict={}
for i in df.columns:
    dict[i]=df[i].value_counts().shape[0]
pd.DataFrame(dict,index=['Unique']).transpose()
# Out:
#                  Unique
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870

# %%
df["Journey_day"] = pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.day
df['Journey_month']=pd.to_datetime(df.Date_of_Journey,format='%d/%m/%Y').dt.month
df.head()
# Out:
#        Airline Date_of_Journey    Source  ...  Price Journey_day Journey_month
# 0       IndiGo      24/03/2019  Banglore  ...   3897          24             3
# 1    Air India       1/05/2019   Kolkata  ...   7662           1             5
# 2  Jet Airways       9/06/2019     Delhi  ...  13882           9             6
# 3       IndiGo      12/05/2019   Kolkata  ...   6218          12             5
# 4       IndiGo      01/03/2019  Banglore  ...  13302           1             3
#
# [5 rows x 13 columns]

# %%
df.drop(['Date_of_Journey'],axis=1,inplace=True)
df.head()
# Out:
#        Airline    Source Destination  ...  Price Journey_day Journey_month
# 0       IndiGo  Banglore   New Delhi  ...   3897          24             3
# 1    Air India   Kolkata    Banglore  ...   7662           1             5
# 2  Jet Airways     Delhi      Cochin  ...  13882           9             6
# 3       IndiGo   Kolkata    Banglore  ...   6218          12             5
# 4       IndiGo  Banglore   New Delhi  ...  13302           1             3
#
# [5 rows x 12 columns]

# %%
df['deprtd_hr']=pd.to_datetime(df['Dep_Time']).dt.hour
df['deprtd_min']=pd.to_datetime(df['Dep_Time']).dt.minute
df.head()
# Out:
#        Airline    Source Destination  ... Journey_month deprtd_hr deprtd_min
# 0       IndiGo  Banglore   New Delhi  ...             3        22         20
# 1    Air India   Kolkata    Banglore  ...             5         5         50
# 2  Jet Airways     Delhi      Cochin  ...             6         9         25
# 3       IndiGo   Kolkata    Banglore  ...             5        18          5
# 4       IndiGo  Banglore   New Delhi  ...             3        16         50
#
# [5 rows x 14 columns]

# %%
df.drop(['Dep_Time'],axis=1,inplace=True)
df.head()
# Out:
#        Airline    Source Destination  ... Journey_month deprtd_hr deprtd_min
# 0       IndiGo  Banglore   New Delhi  ...             3        22         20
# 1    Air India   Kolkata    Banglore  ...             5         5         50
# 2  Jet Airways     Delhi      Cochin  ...             6         9         25
# 3       IndiGo   Kolkata    Banglore  ...             5        18          5
# 4       IndiGo  Banglore   New Delhi  ...             3        16         50
#
# [5 rows x 13 columns]

# %%
df['arr_hr']=pd.to_datetime(df['Arrival_Time']).dt.hour
df['arr_min']=pd.to_datetime(df['Arrival_Time']).dt.minute
df.drop(['Arrival_Time'],axis=1,inplace=True)
df.head()
# Out:
#        Airline    Source Destination  ... deprtd_min arr_hr arr_min
# 0       IndiGo  Banglore   New Delhi  ...         20      1      10
# 1    Air India   Kolkata    Banglore  ...         50     13      15
# 2  Jet Airways     Delhi      Cochin  ...         25      4      25
# 3       IndiGo   Kolkata    Banglore  ...          5     23      30
# 4       IndiGo  Banglore   New Delhi  ...         50     21      35
#
# [5 rows x 14 columns]

# %%
duration=list(df['Duration'])
for i in range(len(duration)):
    if len(duration[i].split()) !=2:
        if 'h' in duration[i]:
            duration[i]=duration[i].strip()+' 0m'
        else:
            duration[i]='0h '+duration[i]

duration_hour=[]
duration_mins=[]
for i in range(len(duration)):
    duration_hour.append(int(duration[i].split(sep='h')[0]))
    duration_mins.append(int(duration[i].split(sep='m')[0].split()[-1]))

# %%
df['duration_hrs']=duration_hour
df['duration_mins']=duration_mins
df.drop(['Duration'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination  ... arr_min duration_hrs duration_mins
# 0       IndiGo  Banglore   New Delhi  ...      10            2            50
# 1    Air India   Kolkata    Banglore  ...      15            7            25
# 2  Jet Airways     Delhi      Cochin  ...      25           19             0
# 3       IndiGo   Kolkata    Banglore  ...      30            5            25
# 4       IndiGo  Banglore   New Delhi  ...      35            4            45
#
# [5 rows x 15 columns]

# %%
df.drop(['Additional_Info','Route'],axis=1,inplace=True)
df.head()
# Out:
#        Airline    Source Destination  ... arr_min  duration_hrs  duration_mins
# 0       IndiGo  Banglore   New Delhi  ...      10             2             50
# 1    Air India   Kolkata    Banglore  ...      15             7             25
# 2  Jet Airways     Delhi      Cochin  ...      25            19              0
# 3       IndiGo   Kolkata    Banglore  ...      30             5             25
# 4       IndiGo  Banglore   New Delhi  ...      35             4             45
#
# [5 rows x 13 columns]

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
df['Total_Stops'].replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4},inplace=True)
df.head()
# Out:
#        Airline    Source Destination  ...  arr_min  duration_hrs  duration_mins
# 0       IndiGo  Banglore   New Delhi  ...       10             2             50
# 1    Air India   Kolkata    Banglore  ...       15             7             25
# 2  Jet Airways     Delhi      Cochin  ...       25            19              0
# 3       IndiGo   Kolkata    Banglore  ...       30             5             25
# 4       IndiGo  Banglore   New Delhi  ...       35             4             45
#
# [5 rows x 13 columns]

# %%
plt.figure(figsize=(30,10))
sns.countplot('Airline',data=df)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Airline', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
sns.catplot(x='Airline',y='Price',data=df.sort_values('Price',ascending=False),kind='boxen',height=8,aspect=3)
plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.catplot(x='Price',y='Source',data=df,kind='boxen')

# %%
sns.catplot(x='Destination',y='Price',data=df,kind='boxen')

# %%
df=pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    Total_Stops  Price  ...  Destination_Kolkata  Destination_New Delhi
# 0            0   3897  ...                    0                      1
# 1            2   7662  ...                    0                      0
# 2            2  13882  ...                    0                      0
# 3            1   6218  ...                    0                      0
# 4            1  13302  ...                    0                      1
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (10682, 30)

# %%
for i in df.columns:
    print (i)
# Out:
# Total_Stops
# Price
# Journey_day
# Journey_month
# deprtd_hr
# deprtd_min
# arr_hr
# arr_min
# duration_hrs
# duration_mins
# Airline_Air India
# Airline_GoAir
# Airline_IndiGo
# Airline_Jet Airways
# Airline_Jet Airways Business
# Airline_Multiple carriers
# Airline_Multiple carriers Premium economy
# Airline_SpiceJet
# Airline_Trujet
# Airline_Vistara
# Airline_Vistara Premium economy
# Source_Chennai
# Source_Delhi
# Source_Kolkata
# Source_Mumbai
# Destination_Cochin
# Destination_Delhi
# Destination_Hyderabad
# Destination_Kolkata
# Destination_New Delhi

# %%
X=df.drop(['Price'],axis=1)
X.head()
# Out:
#    Total_Stops  Journey_day  ...  Destination_Kolkata  Destination_New Delhi
# 0            0           24  ...                    0                      1
# 1            2            1  ...                    0                      0
# 2            2            9  ...                    0                      0
# 3            1           12  ...                    0                      0
# 4            1            1  ...                    0                      1
#
# [5 rows x 29 columns]

# %%
y=df['Price']
y.head()
# Out:
# 0     3897
# 1     7662
# 2    13882
# 3     6218
# 4    13302
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 7)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg=RandomForestRegressor()

# %%
rf_reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rf_reg.predict(X_test)
y_pred
# Out:
# array([14199.0685    ,  3943.        , 10593.36216667, ...,
#        15129.        , 18307.59      , 12633.88666667])

# %%
rf_reg.score(X_test,y_test)
# Out:
# 0.8264727440766877

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 20)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 1000]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = rf_reg, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1100; total time=  41.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1100; total time=  48.8s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1100; total time=  42.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1100; total time=  38.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=1100; total time=  38.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   8.1s
# [CV] END max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.4s
# [CV] END max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.4s
# [CV] END max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.5s
# [CV] END max_depth=7, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   3.9s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=1000, n_estimators=1100; total time=   5.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=1000, n_estimators=1100; total time=  10.3s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=1000, n_estimators=1100; total time=   9.0s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=1000, n_estimators=1100; total time=   9.7s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=2, min_samples_split=1000, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=  11.4s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   8.1s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=  12.4s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=  10.2s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=700; total time=   8.8s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=1000, n_estimators=1200; total time=  16.2s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=1000, n_estimators=1200; total time=  13.0s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=1000, n_estimators=1200; total time=  12.0s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=1000, n_estimators=1200; total time=  12.2s
# [CV] END max_depth=21, max_features=auto, min_samples_leaf=10, min_samples_split=1000, n_estimators=1200; total time=  13.2s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  10.6s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  10.5s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=   9.4s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=   8.7s
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=   8.9s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=1000, n_estimators=1300; total time=   4.0s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=1000, n_estimators=1300; total time=   4.4s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=1000, n_estimators=1300; total time=   4.7s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=1000, n_estimators=1300; total time=   5.1s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=5, min_samples_split=1000, n_estimators=1300; total time=   5.0s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=  47.0s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=  47.5s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=  40.5s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=  44.9s
# [CV] END max_depth=24, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1500; total time=  41.3s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.6s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.7s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.6s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.7s
# [CV] END max_depth=24, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.6s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 7, 10, 13, 16, 18, 21,
#                                                       24, 27, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               1000],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100, 1200,
#                                                          1300, 1400, 1500, 1600,
#                                                          1700, 1800, 1900,
#                                                          2000]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1500,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 24}

# %%
from sklearn.metrics import accuracy_score
model = RandomForestRegressor(n_estimators = 1500,
 min_samples_split = 5,
 min_samples_leaf =  2,
 max_features = 'auto',
 max_depth =  24)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.8390119076221325

# %%
#import joblib 
#joblib.dump(model,"Flight_Ticket_Prediction_Model")
#model=joblib.load('Flight_Ticket_Prediction_Model')
